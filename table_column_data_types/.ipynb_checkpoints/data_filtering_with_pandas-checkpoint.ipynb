# %%
import pandas as pd
from datetime import datetime

# %%
expanded_radet_w25=pd.read_csv('KPC2_COMBINED RADET_14-06-2024_processed.csv')
# Out:
# C:\Users\5300\AppData\Local\Temp\ipykernel_20384\3247848534.py:1: DtypeWarning: Columns (42,43,44,45,49,53,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   expanded_radet_w25=pd.read_csv('KPC2_COMBINED RADET_14-06-2024_processed.csv')

# %%
expanded_radet_w25.head()
# Out:
#     period     datim_id   state     lga   facilityname  \
# 0  2024W25  xCya42gPOnU  Bauchi  Bauchi  Bauchi KP OSS
# 1  2024W25  xCya42gPOnU  Bauchi  Bauchi  Bauchi KP OSS
# 2  2024W25  xCya42gPOnU  Bauchi  Bauchi  Bauchi KP OSS
# 3  2024W25  xCya42gPOnU  Bauchi  Bauchi  Bauchi KP OSS
# 4  2024W25  xCya42gPOnU  Bauchi  Bauchi  Bauchi KP OSS
#
#                        uniquepersonuuid hospitalnumber  gender targetgroup  \
# 0  000c08a2-0520-4bf7-aa77-e610b24b3458       BABA0870  Female        PWID
# 1  000e5067-0596-4c6c-b1ca-5b17ac24c6ee    BA/TRR/0156  Female         FSW
# 2  002921bd-83be-4129-afda-cabfa14c34d9    BA/TRR/0721  Female         FSW
# 3  0032ad84-ce86-467b-970c-de25f11403a7    BA/TRR/1044  Female          SP
# 4  0035b9fa-0de0-4cb4-8abe-7ea577300664       BABA0399    Male        PWID
#
#    currentweight  ... resultofcervicalcancerscreening datebiometricsenrolled  \
# 0           81.0  ...                             NaN              6/16/2021
# 1           59.0  ...                             NaN               8/6/2021
# 2           67.0  ...                        Negative               8/3/2023
# 3           52.0  ...                        Negative             11/12/2021
# 4           72.0  ...                             NaN               6/8/2021
#
#   numberoffingerscaptured causeofdeath cervicalcancertreatmentscreened  \
# 0                     6.0          NaN                             NaN
# 1                     6.0          NaN                             NaN
# 2                    10.0          NaN                             NaN
# 3                     6.0          NaN                             NaN
# 4                     6.0          NaN                             NaN
#
#    dateofcurrentviralloadsample dateofvleligibilitystatus vleligibilitystatus  \
# 0                     5/20/2024                       NaN               False
# 1                     10/4/2023                 4/23/2024                True
# 2                    11/15/2023                       NaN               False
# 3                     2/21/2024                       NaN               False
# 4                    12/19/2023                       NaN               False
#
#               tbstatusoutcome treatmentmethoddate
# 0  No signs or symptoms of TB                 NaN
# 1  No signs or symptoms of TB                 NaN
# 2  No signs or symptoms of TB                 NaN
# 3  No signs or symptoms of TB                 NaN
# 4  No signs or symptoms of TB                 NaN
#
# [5 rows x 75 columns]

# %%
# df = expanded_radet_w21.query('datim_id=="AFtz58N0L6c"')

# %%
def _date_validation(df):
        date_columns = [col for col in df.columns if col.startswith('date_') or col.endswith('_date')]
        
        if not date_columns:
            return {}  # No date columns to validate
        
        problematic_dates = {}
        
        for col in date_columns:
            try:
                pd.to_datetime(df[col], errors='raise')
            except (TypeError, ValueError) as e:
                problematic_dates[col] = []
                for idx, value in df[col].items():
                    try:
                        pd.to_datetime(value, errors='raise')
                    except (TypeError, ValueError):
                        problematic_dates[col].append(f'record {idx+1}, value => {value}')
        
        return problematic_dates
    
validation_result=_date_validation(expanded_radet_w25)
validation_result
# Out:
# {}
